# %% [markdown]
# # Gesture Recognition
# Project submitted by:
# - Swapnil Disawal
# - Raja Rajalakshmi.K
#
# A home electronics company that manufactures state of the art smart televisions want to develop a cool feature in the smart-TV that can recognize five different gestures performed by the user which will help users control the TV without using a remote.
# The gestures are continuously monitored by the webcam mounted on the TV. Each gesture corresponds to a specific command:
# - 1.Thumbs up:  Increase the volume
# - 2.Thumbs down: Decrease the volume
# - 3.Left swipe: 'Jump' backwards 10 seconds
# - 4.Right swipe: 'Jump' forward 10 seconds
# - 5.Stop: Pause the movie

# %%
import numpy as np
import os
from scipy.misc import imread, imresize
import datetime
import os
import cv2

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
np.random.seed(30)
import random as rn
rn.seed(30)
from keras import backend as K
import tensorflow as tf
tf.set_random_seed(30)

# %% [markdown]
# In this block, you read the folder names for training and validation. We will set the initial `batch_size` here. Note that we will experimentally set the batch size in such a way that you are able to use the GPU in full capacity. Keep increasing the batch size until the machine throws an error.

# %%
train_doc = np.random.permutation(open('train.csv').readlines())
val_doc = np.random.permutation(open('val.csv').readlines())
batch_size = 10 #experiment with the batch size

# %% [markdown]
# ***Note*** in our implementaiton true **batch_size** is always 2 fold as we agument our data. if if batch size is 10, true batch size at the run time is 20, as twice the number of data set loaded are added to the batch

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator is broken down into modules. In the generator, we are going to preprocess the images as we have images of 2 different dimensions as well as create a batch of video frames.

# %%
# Parameters initialization
nb_rows = 120   # X dimension of the image
nb_cols = 120   # Y dimesnion of the image
#total_frames = 30
nb_frames = 30  # lenght of the video frames
nb_channel = 3 # numbe rof channels in images 3 for color(RGB) and 1 for Gray

# %%
#  generate a random affine transform on the iamge
def get_random_affine():
    dx, dy = np.random.randint(-1.7, 1.8, 2)
    M = np.float32([[1, 0, dx], [0, 1, dy]])
    return M

# %%
#  normalise the data
def normalize_data(data):
    return data/127.5-1

# %%
#  normalise the data 2
def normalize_image(img):
    normalized_image= img - np.percentile(img,15)/ np.percentile(img,85) - np.percentile(img,15)
    return normalized_image

# %%
#checked the data and if we crop more than 10 pixels some of images having dimesions 
#120X160 are loosing the hand object in image. hence cropping  by 10X10 and then resizing so image wont shrink much too
def crop_and_resize_image(img):
    if img.shape[0] != img.shape[1]:
        img=img[0:120,10:150]
    resized_image = imresize(img, (nb_rows,nb_cols))
    return resized_image

# %%
# initialize all the batch image data and labels
def init_batch_data(batch_size):
    batch_data = np.zeros((batch_size, nb_frames, nb_rows, nb_cols, nb_channel)) 
    batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
    return batch_data, batch_labels

# %%
# load batch data
def load_batch_images(source_path, folder_list, batch_num, batch_size, t,validation):
    
    batch_data,batch_labels = init_batch_data(batch_size)
    
    #  augumented batch data with affine transformation
    batch_data_aug,batch_labels_aug = init_batch_data(batch_size)
    
    #augmented batch data with horizontal flip
    batch_data_flip,batch_labels_flip = init_batch_data(batch_size)
    
    #create a list of image numbers you want to use for a particular video using full frames
    img_idx = [x for x in range(0, nb_frames)] 

    for folder in range(batch_size): # iterate over the batch_size
        # read all the images in the folder
        imgs = sorted(os.listdir(source_path+'/'+ t[folder + (batch_num*batch_size)].split(';')[0])) 
        # Generate a random affine to be used in image transformation for buidling agumented data set
        M = get_random_affine()
        
        #  Iterate over the frames/images of a folder to read them in
        for idx, item in enumerate(img_idx): 
            ## image = imread(source_path+'/'+ t[folder + (batch_num*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
            image = cv2.imread(source_path+'/'+ t[folder + (batch_num*batch_size)].strip().split(';')[0]+'/'+imgs[item], cv2.IMREAD_COLOR)
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            
            # Cropping uneven frames
            if image.shape[0] != image.shape[1]:
                image=image[0:120,20:140]
            
            #crop the images and resize them.    
            resized = cv2.resize(image, (nb_rows,nb_cols), interpolation = cv2.INTER_AREA)
            #Normal data
            batch_data[folder,idx] = (resized)
            
            #Data with affine transformation
            batch_data_aug[folder,idx] = (cv2.warpAffine(resized, M, (resized.shape[0], resized.shape[1])))
            
            # Data with horizontal flip
            batch_data_flip[folder,idx]= np.flip(resized,1)

        batch_labels[folder, int(t[folder + (batch_num*batch_size)].strip().split(';')[2])] = 1
        batch_labels_aug[folder, int(t[folder + (batch_num*batch_size)].strip().split(';')[2])] = 1
        
        # Labeling data with horizobtal flip, right swipe becomes left swipe and viceversa
        if int(t[folder + (batch_num*batch_size)].strip().split(';')[2])==0:
                    batch_labels_flip[folder, 1] = 1
        elif int(t[folder + (batch_num*batch_size)].strip().split(';')[2])==1:
                    batch_labels_flip[folder, 0] = 1
                    
        else:
                    batch_labels_flip[folder, int(t[folder + (batch_num*batch_size)].strip().split(';')[2])] = 1
                  
    
    batch_data_final = np.append(batch_data, batch_data_aug, axis = 0)
    batch_data_final = np.append(batch_data_final, batch_data_flip, axis = 0)

    batch_labels_final = np.append(batch_labels, batch_labels_aug, axis = 0) 
    batch_labels_final = np.append(batch_labels_final, batch_labels_flip, axis = 0)
    
    if validation:
        batch_data_final=batch_data
        batch_labels_final= batch_labels
        
    return batch_data_final,batch_labels_final

# %%
def generator(source_path, folder_list, batch_size, validation=False):
    print( 'Source path = ', source_path, '; batch size =', batch_size)
    while True:
        t = np.random.permutation(folder_list)
        num_batches = len(folder_list)//batch_size # calculate the number of batches
        for batch in range(num_batches): # we iterate over the number of batches
            # you yield the batch_data and the batch_labels, remember what does yield do
            yield load_batch_images(source_path, folder_list, batch, batch_size, t,validation)
            

        
        # Code for the remaining data points which are left after full batches
        if (len(folder_list) != batch_size*num_batches):
            batch_size = len(folder_list) - (batch_size*num_batches)
            yield load_batch_images(source_path, folder_list, batch, batch_size, t,validation)

# %%
# for RNN
def get_batchdata_affinetransform(source_path, folder_list, batch_num, batch_size, t,validation):
    
    batch_data,batch_labels = init_batch_data(batch_size)
    
    # We will also build an augumented batch data with affine transformation
    batch_data_aug,batch_labels_aug = init_batch_data(batch_size)
    
   
    #create a list of image numbers you want to use for a particular video using full frames
    img_idx = [x for x in range(0, nb_frames)] 

    for folder in range(batch_size): # iterate over the batch_size
        # read all the images in the folder
        imgs = sorted(os.listdir(source_path+'/'+ t[folder + (batch_num*batch_size)].split(';')[0])) 
        # Generate a random affine to be used in image transformation for buidling agumented data set
        M = get_random_affine()
        
        #  Iterate over the frames/images of a folder to read them in
        for idx, item in enumerate(img_idx): 
            image = cv2.imread(source_path+'/'+ t[folder + (batch_num*batch_size)].strip().split(';')[0]+'/'+imgs[item], cv2.IMREAD_COLOR)
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            
            # resize image
            
            resized_image=crop_and_resize_image(image)
            
            #Normal data
            batch_data[folder,idx,:,:,0] = normalize_image(resized_image[:, : , 0])#normalise and feed in the image
            batch_data[folder,idx,:,:,1] = normalize_image(resized_image[:, : , 1])#normalise and feed in the image
            batch_data[folder,idx,:,:,2] = normalize_image(resized_image[:, : , 2])#normalise and feed in the image
            
           #Data with affine transformation
            batch_data_aug[folder,idx] = (cv2.warpAffine(resized_image, M, (resized_image.shape[0], resized_image.shape[1])))
            

        batch_labels[folder, int(t[folder + (batch_num*batch_size)].strip().split(';')[2])] = 1
        batch_labels_aug[folder, int(t[folder + (batch_num*batch_size)].strip().split(';')[2])] = 1
               
                  
    
    batch_data_final = np.append(batch_data, batch_data_aug, axis = 0)
    batch_labels_final = np.append(batch_labels, batch_labels_aug, axis = 0) 

    
    if validation:
        batch_data_final=batch_data
        batch_labels_final= batch_labels
        
    return batch_data_final,batch_labels_final

# %%
# for RNN
def generator_augmentation(source_path, folder_list, batch_size, validation=False,ablation=None):
    print( 'Source path = ', source_path, '; batch size =', batch_size)
    if(ablation!=None):
        folder_list=folder_list[:ablation]
    while True:
        t = np.random.permutation(folder_list)
        num_batches = len(folder_list)//batch_size # calculate the number of batches
        for batch in range(num_batches): # we iterate over the number of batches
            # you yield the batch_data and the batch_labels, remember what does yield do
            yield get_batchdata_affinetransform(source_path, folder_list, batch, batch_size, t,validation)
            
        
        # Code for the remaining data points which are left after full batches
        if (len(folder_list) != batch_size*num_batches):
            batch_size = len(folder_list) - (batch_size*num_batches)
            yield get_batchdata_affinetransform(source_path, folder_list, batch, batch_size, t,validation)

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
curr_dt_time = datetime.datetime.now()
train_path = 'train'
val_path = 'val'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_epochs = 10 # choose the number of epochs
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 10

# %% [markdown]
# ## Final Model

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation, Dropout
from keras.layers.convolutional import Conv3D, MaxPooling3D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.losses import categorical_crossentropy
from keras.optimizers import Adam

nb_filters = [8,16,32,64]
nb_dense = [256, 128, 5]

# Input
input_shape=(nb_frames,nb_rows,nb_cols,nb_channel)

# Define model
model = Sequential()

model.add(Conv3D(nb_filters[0], 
                 kernel_size=(3,3,3), 
                 input_shape=input_shape,
                 padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Conv3D(nb_filters[1], 
                 kernel_size=(3,3,3), 
                 padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Conv3D(nb_filters[2], 
                 kernel_size=(1,3,3), 
                 padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Conv3D(nb_filters[3], 
                 kernel_size=(1,3,3), 
                 padding='same'))
model.add(Activation('relu'))
model.add(Dropout(0.25))

model.add(MaxPooling3D(pool_size=(2,2,2)))

#Flatten Layers
model.add(Flatten())

model.add(Dense(nb_dense[0], activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(nb_dense[1], activation='relu'))
model.add(Dropout(0.5))

#softmax layer
model.add(Dense(nb_dense[2], activation='softmax'))

# %% [markdown]
# Now that you have written the model, the next step is to `compile` the model. When you print the `summary` of the model, you'll see the total number of parameters you have to train.

# %%
optimiser = Adam() #write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_1 (Conv3D)            (None, 30, 120, 120, 8)   656
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 30, 120, 120, 8)   32
# _________________________________________________________________
# activation_1 (Activation)    (None, 30, 120, 120, 8)   0
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 15, 60, 60, 8)     0
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, 15, 60, 60, 16)    3472
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 15, 60, 60, 16)    64
# _________________________________________________________________
# activation_2 (Activation)    (None, 15, 60, 60, 16)    0
# _________________________________________________________________
# max_pooling3d_2 (MaxPooling3 (None, 7, 30, 30, 16)     0
# _________________________________________________________________
# conv3d_3 (Conv3D)            (None, 7, 30, 30, 32)     4640
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 7, 30, 30, 32)     128
# _________________________________________________________________
# activation_3 (Activation)    (None, 7, 30, 30, 32)     0
# _________________________________________________________________
# max_pooling3d_3 (MaxPooling3 (None, 3, 15, 15, 32)     0
# _________________________________________________________________
# conv3d_4 (Conv3D)            (None, 3, 15, 15, 64)     18496
# _________________________________________________________________
# activation_4 (Activation)    (None, 3, 15, 15, 64)     0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 3, 15, 15, 64)     0
# _________________________________________________________________
# max_pooling3d_4 (MaxPooling3 (None, 1, 7, 7, 64)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3136)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               803072
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 5)                 645
# =================================================================
# Total params: 864,101
# Trainable params: 863,989
# Non-trainable params: 112
# _________________________________________________________________
# None

# %% [markdown]
# Let us create the `train_generator` and the `val_generator` which will be used in `.fit_generator`.

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size,validation=True)

# %%
model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)

# write the Reducelronplateau code here
LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, cooldown=1, verbose=1)
callbacks_list = [checkpoint, LR]

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %% [markdown]
# ## CNN_Model1

# %%
batch_size = 10
num_epochs = 20
model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  val ; batch size = 10
# Source path =  train ; batch size = 10
# Epoch 1/20
# 67/67 [==============================] - 184s 3s/step - loss: 1.7311 - categorical_accuracy: 0.2613 - val_loss: 1.2905 - val_categorical_accuracy: 0.4300
#
# Epoch 00001: saving model to model_init_2020-07-1220_19_19.720565/model-00001-1.73360-0.25943-1.29050-0.43000.h5
# Epoch 2/20
# 67/67 [==============================] - 40s 604ms/step - loss: 1.5027 - categorical_accuracy: 0.3300 - val_loss: 1.1888 - val_categorical_accuracy: 0.4800
#
# Epoch 00002: saving model to model_init_2020-07-1220_19_19.720565/model-00002-1.50275-0.33002-1.18878-0.48000.h5
# Epoch 3/20
# 67/67 [==============================] - 35s 526ms/step - loss: 1.3387 - categorical_accuracy: 0.4063 - val_loss: 1.1991 - val_categorical_accuracy: 0.5400
#
# Epoch 00003: saving model to model_init_2020-07-1220_19_19.720565/model-00003-1.33868-0.40630-1.19913-0.54000.h5
# Epoch 4/20
# 67/67 [==============================] - 28s 425ms/step - loss: 1.2946 - categorical_accuracy: 0.4511 - val_loss: 1.8225 - val_categorical_accuracy: 0.3000
#
# Epoch 00004: saving model to model_init_2020-07-1220_19_19.720565/model-00004-1.29457-0.45108-1.82252-0.30000.h5
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 5/20
# 67/67 [==============================] - 28s 421ms/step - loss: 1.1881 - categorical_accuracy: 0.5290 - val_loss: 1.0444 - val_categorical_accuracy: 0.5600
#
# Epoch 00005: saving model to model_init_2020-07-1220_19_19.720565/model-00005-1.18812-0.52902-1.04444-0.56000.h5
# Epoch 6/20
# 67/67 [==============================] - 29s 430ms/step - loss: 1.0652 - categorical_accuracy: 0.5920 - val_loss: 1.3456 - val_categorical_accuracy: 0.4400
#
# Epoch 00006: saving model to model_init_2020-07-1220_19_19.720565/model-00006-1.06524-0.59204-1.34557-0.44000.h5
# Epoch 7/20
# 67/67 [==============================] - 29s 437ms/step - loss: 1.0346 - categorical_accuracy: 0.5887 - val_loss: 0.9647 - val_categorical_accuracy: 0.6400
#
# Epoch 00007: saving model to model_init_2020-07-1220_19_19.720565/model-00007-1.03460-0.58872-0.96475-0.64000.h5
# Epoch 8/20
# 67/67 [==============================] - 28s 425ms/step - loss: 0.9947 - categorical_accuracy: 0.6053 - val_loss: 0.8681 - val_categorical_accuracy: 0.6800
#
# Epoch 00008: saving model to model_init_2020-07-1220_19_19.720565/model-00008-0.99472-0.60531-0.86813-0.68000.h5
# Epoch 9/20
# 67/67 [==============================] - 29s 435ms/step - loss: 0.8656 - categorical_accuracy: 0.6368 - val_loss: 0.9979 - val_categorical_accuracy: 0.6200
#
# Epoch 00009: saving model to model_init_2020-07-1220_19_19.720565/model-00009-0.86565-0.63682-0.99789-0.62000.h5
# Epoch 10/20
# 67/67 [==============================] - 28s 415ms/step - loss: 0.9402 - categorical_accuracy: 0.6119 - val_loss: 0.8074 - val_categorical_accuracy: 0.7200
#
# Epoch 00010: saving model to model_init_2020-07-1220_19_19.720565/model-00010-0.94017-0.61194-0.80744-0.72000.h5
# Epoch 11/20
# 67/67 [==============================] - 29s 434ms/step - loss: 0.7806 - categorical_accuracy: 0.7164 - val_loss: 1.4945 - val_categorical_accuracy: 0.5700
#
# Epoch 00011: saving model to model_init_2020-07-1220_19_19.720565/model-00011-0.78064-0.71642-1.49447-0.57000.h5
# Epoch 12/20
# 67/67 [==============================] - 28s 423ms/step - loss: 0.7812 - categorical_accuracy: 0.6915 - val_loss: 0.7283 - val_categorical_accuracy: 0.7500
#
# Epoch 00012: saving model to model_init_2020-07-1220_19_19.720565/model-00012-0.78124-0.69154-0.72834-0.75000.h5
# Epoch 13/20
# 67/67 [==============================] - 29s 435ms/step - loss: 0.7011 - categorical_accuracy: 0.7347 - val_loss: 1.5534 - val_categorical_accuracy: 0.5600
#
# Epoch 00013: saving model to model_init_2020-07-1220_19_19.720565/model-00013-0.70112-0.73466-1.55343-0.56000.h5
# Epoch 14/20
# 67/67 [==============================] - 28s 422ms/step - loss: 0.7566 - categorical_accuracy: 0.7197 - val_loss: 0.6263 - val_categorical_accuracy: 0.7700
#
# Epoch 00014: saving model to model_init_2020-07-1220_19_19.720565/model-00014-0.75664-0.71973-0.62632-0.77000.h5
# Epoch 15/20
# 67/67 [==============================] - 28s 425ms/step - loss: 0.5707 - categorical_accuracy: 0.7910 - val_loss: 0.6791 - val_categorical_accuracy: 0.7200
#
# Epoch 00015: saving model to model_init_2020-07-1220_19_19.720565/model-00015-0.57065-0.79104-0.67908-0.72000.h5
# Epoch 16/20
# 67/67 [==============================] - 28s 423ms/step - loss: 0.7132 - categorical_accuracy: 0.7645 - val_loss: 0.6131 - val_categorical_accuracy: 0.7300
#
# Epoch 00016: saving model to model_init_2020-07-1220_19_19.720565/model-00016-0.71323-0.76451-0.61307-0.73000.h5
# Epoch 17/20
# 67/67 [==============================] - 29s 433ms/step - loss: 0.6319 - categorical_accuracy: 0.7711 - val_loss: 0.6605 - val_categorical_accuracy: 0.7300
#
# Epoch 00017: saving model to model_init_2020-07-1220_19_19.720565/model-00017-0.63185-0.77114-0.66051-0.73000.h5
# Epoch 18/20
# 67/67 [==============================] - 29s 430ms/step - loss: 0.5438 - categorical_accuracy: 0.7877 - val_loss: 0.5089 - val_categorical_accuracy: 0.7800
#
# Epoch 00018: saving model to model_init_2020-07-1220_19_19.720565/model-00018-0.54379-0.78773-0.50892-0.78000.h5
# Epoch 19/20
# 67/67 [==============================] - 28s 417ms/step - loss: 0.5721 - categorical_accuracy: 0.8126 - val_loss: 0.5722 - val_categorical_accuracy: 0.7800
#
# Epoch 00019: saving model to model_init_2020-07-1220_19_19.720565/model-00019-0.57207-0.81260-0.57219-0.78000.h5
# Epoch 20/20
# 67/67 [==============================] - 28s 416ms/step - loss: 0.5421 - categorical_accuracy: 0.8027 - val_loss: 0.5655 - val_categorical_accuracy: 0.7700
#
# Epoch 00020: saving model to model_init_2020-07-1220_19_19.720565/model-00020-0.54213-0.80265-0.56550-0.77000.h5
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.

# %% [markdown]
# ## CNN_Model2

# %%
batch_size = 20
num_epochs = 20

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/20
# 34/34 [==============================] - 17s 499ms/step - loss: 0.3793 - categorical_accuracy: 0.8693 - val_loss: 0.5235 - val_categorical_accuracy: 0.7800
#
# Epoch 00001: saving model to model_init_2020-07-1220_19_19.720565/model-00001-0.37929-0.86928-0.52352-0.78000.h5
# Epoch 2/20
# 34/34 [==============================] - 14s 426ms/step - loss: 0.3257 - categorical_accuracy: 0.8725 - val_loss: 0.7019 - val_categorical_accuracy: 0.7200
#
# Epoch 00002: saving model to model_init_2020-07-1220_19_19.720565/model-00002-0.32575-0.87255-0.70187-0.72000.h5
# Epoch 3/20
# 34/34 [==============================] - 13s 393ms/step - loss: 0.3907 - categorical_accuracy: 0.8431 - val_loss: 0.3280 - val_categorical_accuracy: 0.8600
#
# Epoch 00003: saving model to model_init_2020-07-1220_19_19.720565/model-00003-0.39073-0.84314-0.32804-0.86000.h5
# Epoch 4/20
# 34/34 [==============================] - 14s 402ms/step - loss: 0.4846 - categorical_accuracy: 0.8268 - val_loss: 0.3478 - val_categorical_accuracy: 0.9000
#
# Epoch 00004: saving model to model_init_2020-07-1220_19_19.720565/model-00004-0.48464-0.82680-0.34781-0.90000.h5
# Epoch 5/20
# 34/34 [==============================] - 14s 412ms/step - loss: 0.3995 - categorical_accuracy: 0.8529 - val_loss: 0.3995 - val_categorical_accuracy: 0.8400
#
# Epoch 00005: saving model to model_init_2020-07-1220_19_19.720565/model-00005-0.39954-0.85294-0.39948-0.84000.h5
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 6/20
# 34/34 [==============================] - 14s 405ms/step - loss: 0.2956 - categorical_accuracy: 0.8889 - val_loss: 0.7378 - val_categorical_accuracy: 0.6800
#
# Epoch 00006: saving model to model_init_2020-07-1220_19_19.720565/model-00006-0.29559-0.88889-0.73782-0.68000.h5
# Epoch 7/20
# 34/34 [==============================] - 14s 415ms/step - loss: 0.2506 - categorical_accuracy: 0.8758 - val_loss: 0.4726 - val_categorical_accuracy: 0.8200
#
# Epoch 00007: saving model to model_init_2020-07-1220_19_19.720565/model-00007-0.25059-0.87582-0.47261-0.82000.h5
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 8/20
# 34/34 [==============================] - 13s 396ms/step - loss: 0.3659 - categorical_accuracy: 0.8725 - val_loss: 0.4373 - val_categorical_accuracy: 0.8200
#
# Epoch 00008: saving model to model_init_2020-07-1220_19_19.720565/model-00008-0.36594-0.87255-0.43728-0.82000.h5
# Epoch 9/20
# 34/34 [==============================] - 13s 396ms/step - loss: 0.4339 - categorical_accuracy: 0.8399 - val_loss: 0.4735 - val_categorical_accuracy: 0.8400
#
# Epoch 00009: saving model to model_init_2020-07-1220_19_19.720565/model-00009-0.43388-0.83987-0.47349-0.84000.h5
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 10/20
# 34/34 [==============================] - 15s 427ms/step - loss: 0.3008 - categorical_accuracy: 0.8954 - val_loss: 0.4279 - val_categorical_accuracy: 0.7800
#
# Epoch 00010: saving model to model_init_2020-07-1220_19_19.720565/model-00010-0.30080-0.89542-0.42792-0.78000.h5
# Epoch 11/20
# 34/34 [==============================] - 14s 407ms/step - loss: 0.2208 - categorical_accuracy: 0.9248 - val_loss: 0.4902 - val_categorical_accuracy: 0.7800
#
# Epoch 00011: saving model to model_init_2020-07-1220_19_19.720565/model-00011-0.22084-0.92484-0.49019-0.78000.h5
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 12/20
# 34/34 [==============================] - 14s 414ms/step - loss: 0.2863 - categorical_accuracy: 0.8824 - val_loss: 0.6513 - val_categorical_accuracy: 0.7800
#
# Epoch 00012: saving model to model_init_2020-07-1220_19_19.720565/model-00012-0.28632-0.88235-0.65129-0.78000.h5
# Epoch 13/20
# 34/34 [==============================] - 14s 412ms/step - loss: 0.3014 - categorical_accuracy: 0.8889 - val_loss: 0.3407 - val_categorical_accuracy: 0.8400
#
# Epoch 00013: saving model to model_init_2020-07-1220_19_19.720565/model-00013-0.30138-0.88889-0.34073-0.84000.h5
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 14/20
# 34/34 [==============================] - 13s 387ms/step - loss: 0.2370 - categorical_accuracy: 0.9183 - val_loss: 0.2300 - val_categorical_accuracy: 0.9000
#
# Epoch 00014: saving model to model_init_2020-07-1220_19_19.720565/model-00014-0.23697-0.91830-0.22997-0.90000.h5
# Epoch 15/20
# 34/34 [==============================] - 14s 414ms/step - loss: 0.3098 - categorical_accuracy: 0.8856 - val_loss: 0.5594 - val_categorical_accuracy: 0.8200
#
# Epoch 00015: saving model to model_init_2020-07-1220_19_19.720565/model-00015-0.30980-0.88562-0.55939-0.82000.h5
# Epoch 16/20
# 34/34 [==============================] - 14s 402ms/step - loss: 0.2655 - categorical_accuracy: 0.9150 - val_loss: 0.3213 - val_categorical_accuracy: 0.8600
#
# Epoch 00016: saving model to model_init_2020-07-1220_19_19.720565/model-00016-0.26551-0.91503-0.32128-0.86000.h5
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 17/20
# 34/34 [==============================] - 14s 425ms/step - loss: 0.3291 - categorical_accuracy: 0.8693 - val_loss: 0.3054 - val_categorical_accuracy: 0.8400
#
# Epoch 00017: saving model to model_init_2020-07-1220_19_19.720565/model-00017-0.32907-0.86928-0.30538-0.84000.h5
# Epoch 18/20
# 34/34 [==============================] - 14s 420ms/step - loss: 0.3289 - categorical_accuracy: 0.8725 - val_loss: 0.7410 - val_categorical_accuracy: 0.7800
#
# Epoch 00018: saving model to model_init_2020-07-1220_19_19.720565/model-00018-0.32895-0.87255-0.74103-0.78000.h5
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 19/20
# 34/34 [==============================] - 14s 400ms/step - loss: 0.2442 - categorical_accuracy: 0.9052 - val_loss: 0.3536 - val_categorical_accuracy: 0.8400
#
# Epoch 00019: saving model to model_init_2020-07-1220_19_19.720565/model-00019-0.24425-0.90523-0.35359-0.84000.h5
# Epoch 20/20
# 34/34 [==============================] - 14s 412ms/step - loss: 0.2942 - categorical_accuracy: 0.8791 - val_loss: 0.3620 - val_categorical_accuracy: 0.8000
#
# Epoch 00020: saving model to model_init_2020-07-1220_19_19.720565/model-00020-0.29419-0.87908-0.36205-0.80000.h5
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.

# %% [markdown]
# ## CNN_Model3

# %%
batch_size = 30
num_epochs = 30

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/30
# 23/23 [==============================] - 10s 433ms/step - loss: 0.2231 - categorical_accuracy: 0.9179 - val_loss: 0.4628 - val_categorical_accuracy: 0.7500
#
# Epoch 00001: saving model to model_init_2020-07-1220_19_19.720565/model-00001-0.22308-0.91787-0.46280-0.75000.h5
# Epoch 2/30
# 23/23 [==============================] - 10s 428ms/step - loss: 0.2945 - categorical_accuracy: 0.8937 - val_loss: 0.5005 - val_categorical_accuracy: 0.8000
#
# Epoch 00002: saving model to model_init_2020-07-1220_19_19.720565/model-00002-0.29449-0.89372-0.50048-0.80000.h5
# Epoch 3/30
# 23/23 [==============================] - 9s 388ms/step - loss: 0.2410 - categorical_accuracy: 0.9179 - val_loss: 0.2845 - val_categorical_accuracy: 0.9250
#
# Epoch 00003: saving model to model_init_2020-07-1220_19_19.720565/model-00003-0.24102-0.91787-0.28454-0.92500.h5
# Epoch 4/30
# 23/23 [==============================] - 10s 435ms/step - loss: 0.3017 - categorical_accuracy: 0.8889 - val_loss: 0.4062 - val_categorical_accuracy: 0.8000
#
# Epoch 00004: saving model to model_init_2020-07-1220_19_19.720565/model-00004-0.30170-0.88889-0.40621-0.80000.h5
# Epoch 5/30
# 23/23 [==============================] - 10s 441ms/step - loss: 0.2463 - categorical_accuracy: 0.9082 - val_loss: 0.5238 - val_categorical_accuracy: 0.8250
#
# Epoch 00005: saving model to model_init_2020-07-1220_19_19.720565/model-00005-0.24633-0.90821-0.52384-0.82500.h5
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 6/30
# 23/23 [==============================] - 10s 417ms/step - loss: 0.2566 - categorical_accuracy: 0.9179 - val_loss: 0.3587 - val_categorical_accuracy: 0.8500
#
# Epoch 00006: saving model to model_init_2020-07-1220_19_19.720565/model-00006-0.25658-0.91787-0.35872-0.85000.h5
# Epoch 7/30
# 23/23 [==============================] - 10s 432ms/step - loss: 0.2948 - categorical_accuracy: 0.8986 - val_loss: 0.4081 - val_categorical_accuracy: 0.8000
#
# Epoch 00007: saving model to model_init_2020-07-1220_19_19.720565/model-00007-0.29482-0.89855-0.40809-0.80000.h5
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# Epoch 8/30
# 23/23 [==============================] - 10s 427ms/step - loss: 0.2088 - categorical_accuracy: 0.9130 - val_loss: 0.4029 - val_categorical_accuracy: 0.8500
#
# Epoch 00008: saving model to model_init_2020-07-1220_19_19.720565/model-00008-0.20876-0.91304-0.40293-0.85000.h5
# Epoch 9/30
# 23/23 [==============================] - 9s 403ms/step - loss: 0.3004 - categorical_accuracy: 0.9130 - val_loss: 0.3874 - val_categorical_accuracy: 0.8500
#
# Epoch 00009: saving model to model_init_2020-07-1220_19_19.720565/model-00009-0.30037-0.91304-0.38736-0.85000.h5
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# Epoch 10/30
# 23/23 [==============================] - 10s 434ms/step - loss: 0.2628 - categorical_accuracy: 0.9034 - val_loss: 0.4469 - val_categorical_accuracy: 0.8500
#
# Epoch 00010: saving model to model_init_2020-07-1220_19_19.720565/model-00010-0.26280-0.90338-0.44686-0.85000.h5
# Epoch 11/30
# 23/23 [==============================] - 10s 423ms/step - loss: 0.2264 - categorical_accuracy: 0.9324 - val_loss: 0.4158 - val_categorical_accuracy: 0.7500
#
# Epoch 00011: saving model to model_init_2020-07-1220_19_19.720565/model-00011-0.22635-0.93237-0.41583-0.75000.h5
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# Epoch 12/30
# 23/23 [==============================] - 10s 416ms/step - loss: 0.3016 - categorical_accuracy: 0.8841 - val_loss: 0.2727 - val_categorical_accuracy: 0.9250
#
# Epoch 00012: saving model to model_init_2020-07-1220_19_19.720565/model-00012-0.30162-0.88406-0.27272-0.92500.h5
# Epoch 13/30
# 23/23 [==============================] - 9s 404ms/step - loss: 0.2088 - categorical_accuracy: 0.9469 - val_loss: 0.5704 - val_categorical_accuracy: 0.7500
#
# Epoch 00013: saving model to model_init_2020-07-1220_19_19.720565/model-00013-0.20877-0.94686-0.57037-0.75000.h5
# Epoch 14/30
# 23/23 [==============================] - 9s 410ms/step - loss: 0.3161 - categorical_accuracy: 0.9034 - val_loss: 0.3242 - val_categorical_accuracy: 0.8750
#
# Epoch 00014: saving model to model_init_2020-07-1220_19_19.720565/model-00014-0.31615-0.90338-0.32420-0.87500.h5
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# Epoch 15/30
# 23/23 [==============================] - 10s 417ms/step - loss: 0.3217 - categorical_accuracy: 0.8841 - val_loss: 0.5796 - val_categorical_accuracy: 0.7250
#
# Epoch 00015: saving model to model_init_2020-07-1220_19_19.720565/model-00015-0.32169-0.88406-0.57956-0.72500.h5
# Epoch 16/30
# 23/23 [==============================] - 9s 397ms/step - loss: 0.2363 - categorical_accuracy: 0.9372 - val_loss: 0.2944 - val_categorical_accuracy: 0.9000
#
# Epoch 00016: saving model to model_init_2020-07-1220_19_19.720565/model-00016-0.23633-0.93720-0.29440-0.90000.h5
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# Epoch 17/30
# 23/23 [==============================] - 10s 433ms/step - loss: 0.2061 - categorical_accuracy: 0.9565 - val_loss: 0.5908 - val_categorical_accuracy: 0.7750
#
# Epoch 00017: saving model to model_init_2020-07-1220_19_19.720565/model-00017-0.20611-0.95652-0.59082-0.77500.h5
# Epoch 18/30
# 23/23 [==============================] - 9s 399ms/step - loss: 0.3140 - categorical_accuracy: 0.8599 - val_loss: 0.3064 - val_categorical_accuracy: 0.8750
#
# Epoch 00018: saving model to model_init_2020-07-1220_19_19.720565/model-00018-0.31403-0.85990-0.30638-0.87500.h5
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 7.629394893626795e-09.
# Epoch 19/30
# 23/23 [==============================] - 10s 433ms/step - loss: 0.3801 - categorical_accuracy: 0.8744 - val_loss: 0.4733 - val_categorical_accuracy: 0.8750
#
# Epoch 00019: saving model to model_init_2020-07-1220_19_19.720565/model-00019-0.38005-0.87440-0.47329-0.87500.h5
# Epoch 20/30
# 23/23 [==============================] - 10s 442ms/step - loss: 0.2868 - categorical_accuracy: 0.9034 - val_loss: 0.4622 - val_categorical_accuracy: 0.7250
#
# Epoch 00020: saving model to model_init_2020-07-1220_19_19.720565/model-00020-0.28683-0.90338-0.46221-0.72500.h5
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 3.814697446813398e-09.
# Epoch 21/30
# 23/23 [==============================] - 9s 406ms/step - loss: 0.2968 - categorical_accuracy: 0.8937 - val_loss: 0.6146 - val_categorical_accuracy: 0.7750
#
# Epoch 00021: saving model to model_init_2020-07-1220_19_19.720565/model-00021-0.29684-0.89372-0.61457-0.77500.h5
# Epoch 22/30
# 23/23 [==============================] - 10s 423ms/step - loss: 0.2091 - categorical_accuracy: 0.8986 - val_loss: 0.1861 - val_categorical_accuracy: 0.9500
#
# Epoch 00022: saving model to model_init_2020-07-1220_19_19.720565/model-00022-0.20911-0.89855-0.18612-0.95000.h5
# Epoch 23/30
# 23/23 [==============================] - 9s 413ms/step - loss: 0.2522 - categorical_accuracy: 0.8986 - val_loss: 0.3599 - val_categorical_accuracy: 0.8250
#
# Epoch 00023: saving model to model_init_2020-07-1220_19_19.720565/model-00023-0.25217-0.89855-0.35988-0.82500.h5
# Epoch 24/30
# 23/23 [==============================] - 9s 395ms/step - loss: 0.2910 - categorical_accuracy: 0.9082 - val_loss: 0.3554 - val_categorical_accuracy: 0.8000
#
# Epoch 00024: saving model to model_init_2020-07-1220_19_19.720565/model-00024-0.29097-0.90821-0.35536-0.80000.h5
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 1.907348723406699e-09.
# Epoch 25/30
# 23/23 [==============================] - 10s 417ms/step - loss: 0.2806 - categorical_accuracy: 0.9082 - val_loss: 0.5205 - val_categorical_accuracy: 0.8500
#
# Epoch 00025: saving model to model_init_2020-07-1220_19_19.720565/model-00025-0.28063-0.90821-0.52045-0.85000.h5
# Epoch 26/30
# 23/23 [==============================] - 10s 427ms/step - loss: 0.3032 - categorical_accuracy: 0.8744 - val_loss: 0.2987 - val_categorical_accuracy: 0.9000
#
# Epoch 00026: saving model to model_init_2020-07-1220_19_19.720565/model-00026-0.30325-0.87440-0.29867-0.90000.h5
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 9.536743617033494e-10.
# Epoch 27/30
# 23/23 [==============================] - 10s 418ms/step - loss: 0.3336 - categorical_accuracy: 0.8792 - val_loss: 0.3549 - val_categorical_accuracy: 0.8000
#
# Epoch 00027: saving model to model_init_2020-07-1220_19_19.720565/model-00027-0.33358-0.87923-0.35490-0.80000.h5
# Epoch 28/30
# 23/23 [==============================] - 10s 418ms/step - loss: 0.2579 - categorical_accuracy: 0.9130 - val_loss: 0.5649 - val_categorical_accuracy: 0.8000
#
# Epoch 00028: saving model to model_init_2020-07-1220_19_19.720565/model-00028-0.25790-0.91304-0.56490-0.80000.h5
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 4.768371808516747e-10.
# Epoch 29/30
# 23/23 [==============================] - 9s 404ms/step - loss: 0.2001 - categorical_accuracy: 0.9420 - val_loss: 0.2793 - val_categorical_accuracy: 0.8500
#
# Epoch 00029: saving model to model_init_2020-07-1220_19_19.720565/model-00029-0.20013-0.94203-0.27930-0.85000.h5
# Epoch 30/30
# 23/23 [==============================] - 10s 425ms/step - loss: 0.3256 - categorical_accuracy: 0.8744 - val_loss: 0.5524 - val_categorical_accuracy: 0.8000
#
# Epoch 00030: saving model to model_init_2020-07-1220_19_19.720565/model-00030-0.32564-0.87440-0.55236-0.80000.h5
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 2.3841859042583735e-10.

# %% [markdown]
# ## CNN_Model4

# %%
batch_size = 50
num_epochs = 30

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/30
# 14/14 [==============================] - 6s 463ms/step - loss: 0.1716 - categorical_accuracy: 0.9683 - val_loss: 0.3577 - val_categorical_accuracy: 0.9000
#
# Epoch 00001: saving model to model_init_2020-07-1220_19_19.720565/model-00001-0.17155-0.96825-0.35766-0.90000.h5
# Epoch 2/30
# 14/14 [==============================] - 6s 415ms/step - loss: 0.1511 - categorical_accuracy: 0.9524 - val_loss: 0.4889 - val_categorical_accuracy: 0.9000
#
# Epoch 00002: saving model to model_init_2020-07-1220_19_19.720565/model-00002-0.15110-0.95238-0.48887-0.90000.h5
# Epoch 3/30
# 14/14 [==============================] - 6s 447ms/step - loss: 0.2449 - categorical_accuracy: 0.9127 - val_loss: 0.2978 - val_categorical_accuracy: 0.8000
#
# Epoch 00003: saving model to model_init_2020-07-1220_19_19.720565/model-00003-0.24493-0.91270-0.29776-0.80000.h5
# Epoch 4/30
# 14/14 [==============================] - 5s 383ms/step - loss: 0.4464 - categorical_accuracy: 0.7778 - val_loss: 0.2724 - val_categorical_accuracy: 0.9000
#
# Epoch 00004: saving model to model_init_2020-07-1220_19_19.720565/model-00004-0.44643-0.77778-0.27242-0.90000.h5
# Epoch 5/30
# 14/14 [==============================] - 7s 486ms/step - loss: 0.2557 - categorical_accuracy: 0.8968 - val_loss: 0.2968 - val_categorical_accuracy: 0.8500
#
# Epoch 00005: saving model to model_init_2020-07-1220_19_19.720565/model-00005-0.25570-0.89683-0.29676-0.85000.h5
# Epoch 6/30
# 14/14 [==============================] - 6s 402ms/step - loss: 0.3378 - categorical_accuracy: 0.8651 - val_loss: 0.4736 - val_categorical_accuracy: 0.8000
#
# Epoch 00006: saving model to model_init_2020-07-1220_19_19.720565/model-00006-0.33780-0.86508-0.47361-0.80000.h5
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 1.1920929521291868e-10.
# Epoch 7/30
# 14/14 [==============================] - 6s 418ms/step - loss: 0.1973 - categorical_accuracy: 0.9206 - val_loss: 0.3706 - val_categorical_accuracy: 0.8000
#
# Epoch 00007: saving model to model_init_2020-07-1220_19_19.720565/model-00007-0.19726-0.92063-0.37062-0.80000.h5
# Epoch 8/30
# 14/14 [==============================] - 6s 434ms/step - loss: 0.2689 - categorical_accuracy: 0.9127 - val_loss: 0.7432 - val_categorical_accuracy: 0.8000
#
# Epoch 00008: saving model to model_init_2020-07-1220_19_19.720565/model-00008-0.26887-0.91270-0.74324-0.80000.h5
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 5.960464760645934e-11.
# Epoch 9/30
# 14/14 [==============================] - 6s 444ms/step - loss: 0.2859 - categorical_accuracy: 0.9048 - val_loss: 0.3556 - val_categorical_accuracy: 0.8500
#
# Epoch 00009: saving model to model_init_2020-07-1220_19_19.720565/model-00009-0.28592-0.90476-0.35556-0.85000.h5
# Epoch 10/30
# 14/14 [==============================] - 5s 377ms/step - loss: 0.2277 - categorical_accuracy: 0.9206 - val_loss: 0.7719 - val_categorical_accuracy: 0.7500
#
# Epoch 00010: saving model to model_init_2020-07-1220_19_19.720565/model-00010-0.22766-0.92063-0.77193-0.75000.h5
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 2.980232380322967e-11.
# Epoch 11/30
# 14/14 [==============================] - 5s 365ms/step - loss: 0.2313 - categorical_accuracy: 0.9127 - val_loss: 0.4039 - val_categorical_accuracy: 0.8000
#
# Epoch 00011: saving model to model_init_2020-07-1220_19_19.720565/model-00011-0.23134-0.91270-0.40386-0.80000.h5
# Epoch 12/30
# 14/14 [==============================] - 6s 420ms/step - loss: 0.1503 - categorical_accuracy: 0.9683 - val_loss: 0.3148 - val_categorical_accuracy: 0.8500
#
# Epoch 00012: saving model to model_init_2020-07-1220_19_19.720565/model-00012-0.15026-0.96825-0.31480-0.85000.h5
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 1.4901161901614834e-11.
# Epoch 13/30
# 14/14 [==============================] - 6s 448ms/step - loss: 0.2939 - categorical_accuracy: 0.8810 - val_loss: 0.2230 - val_categorical_accuracy: 0.9000
#
# Epoch 00013: saving model to model_init_2020-07-1220_19_19.720565/model-00013-0.29387-0.88095-0.22296-0.90000.h5
# Epoch 14/30
# 14/14 [==============================] - 5s 367ms/step - loss: 0.3186 - categorical_accuracy: 0.8810 - val_loss: 0.4069 - val_categorical_accuracy: 0.8000
#
# Epoch 00014: saving model to model_init_2020-07-1220_19_19.720565/model-00014-0.31859-0.88095-0.40689-0.80000.h5
# Epoch 15/30
# 14/14 [==============================] - 6s 414ms/step - loss: 0.2893 - categorical_accuracy: 0.8968 - val_loss: 0.3330 - val_categorical_accuracy: 0.8500
#
# Epoch 00015: saving model to model_init_2020-07-1220_19_19.720565/model-00015-0.28929-0.89683-0.33298-0.85000.h5
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 7.450580950807417e-12.
# Epoch 16/30
# 14/14 [==============================] - 5s 393ms/step - loss: 0.3901 - categorical_accuracy: 0.8651 - val_loss: 0.4427 - val_categorical_accuracy: 0.7500
#
# Epoch 00016: saving model to model_init_2020-07-1220_19_19.720565/model-00016-0.39011-0.86508-0.44268-0.75000.h5
# Epoch 17/30
# 14/14 [==============================] - 5s 379ms/step - loss: 0.2583 - categorical_accuracy: 0.8968 - val_loss: 0.5314 - val_categorical_accuracy: 0.8500
#
# Epoch 00017: saving model to model_init_2020-07-1220_19_19.720565/model-00017-0.25831-0.89683-0.53139-0.85000.h5
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 3.725290475403709e-12.
# Epoch 18/30
# 14/14 [==============================] - 6s 457ms/step - loss: 0.1656 - categorical_accuracy: 0.9365 - val_loss: 0.5622 - val_categorical_accuracy: 0.7500
#
# Epoch 00018: saving model to model_init_2020-07-1220_19_19.720565/model-00018-0.16565-0.93651-0.56216-0.75000.h5
# Epoch 19/30
# 14/14 [==============================] - 6s 426ms/step - loss: 0.2782 - categorical_accuracy: 0.8889 - val_loss: 0.7165 - val_categorical_accuracy: 0.8000
#
# Epoch 00019: saving model to model_init_2020-07-1220_19_19.720565/model-00019-0.27823-0.88889-0.71649-0.80000.h5
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 1.8626452377018543e-12.
# Epoch 20/30
# 14/14 [==============================] - 5s 392ms/step - loss: 0.2226 - categorical_accuracy: 0.9127 - val_loss: 0.2128 - val_categorical_accuracy: 0.9000
#
# Epoch 00020: saving model to model_init_2020-07-1220_19_19.720565/model-00020-0.22263-0.91270-0.21283-0.90000.h5
# Epoch 21/30
# 14/14 [==============================] - 5s 384ms/step - loss: 0.1715 - categorical_accuracy: 0.9524 - val_loss: 0.2723 - val_categorical_accuracy: 0.8000
#
# Epoch 00021: saving model to model_init_2020-07-1220_19_19.720565/model-00021-0.17149-0.95238-0.27234-0.80000.h5
# Epoch 22/30
# 14/14 [==============================] - 6s 417ms/step - loss: 0.3097 - categorical_accuracy: 0.8810 - val_loss: 0.3763 - val_categorical_accuracy: 0.8500
#
# Epoch 00022: saving model to model_init_2020-07-1220_19_19.720565/model-00022-0.30972-0.88095-0.37626-0.85000.h5
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 9.313226188509272e-13.
# Epoch 23/30
# 14/14 [==============================] - 6s 404ms/step - loss: 0.3300 - categorical_accuracy: 0.8492 - val_loss: 0.6838 - val_categorical_accuracy: 0.8500
#
# Epoch 00023: saving model to model_init_2020-07-1220_19_19.720565/model-00023-0.32996-0.84921-0.68376-0.85000.h5
# Epoch 24/30
# 14/14 [==============================] - 6s 413ms/step - loss: 0.2552 - categorical_accuracy: 0.9127 - val_loss: 0.4228 - val_categorical_accuracy: 0.8500
#
# Epoch 00024: saving model to model_init_2020-07-1220_19_19.720565/model-00024-0.25521-0.91270-0.42281-0.85000.h5
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 4.656613094254636e-13.
# Epoch 25/30
# 14/14 [==============================] - 6s 420ms/step - loss: 0.3590 - categorical_accuracy: 0.8889 - val_loss: 0.2361 - val_categorical_accuracy: 0.8500
#
# Epoch 00025: saving model to model_init_2020-07-1220_19_19.720565/model-00025-0.35898-0.88889-0.23608-0.85000.h5
# Epoch 26/30
# 14/14 [==============================] - 6s 409ms/step - loss: 0.3738 - categorical_accuracy: 0.8889 - val_loss: 0.5260 - val_categorical_accuracy: 0.7000
#
# Epoch 00026: saving model to model_init_2020-07-1220_19_19.720565/model-00026-0.37377-0.88889-0.52603-0.70000.h5
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 2.328306547127318e-13.
# Epoch 27/30
# 14/14 [==============================] - 6s 404ms/step - loss: 0.2563 - categorical_accuracy: 0.9365 - val_loss: 0.3274 - val_categorical_accuracy: 0.9000
#
# Epoch 00027: saving model to model_init_2020-07-1220_19_19.720565/model-00027-0.25628-0.93651-0.32737-0.90000.h5
# Epoch 28/30
# 14/14 [==============================] - 5s 387ms/step - loss: 0.4299 - categorical_accuracy: 0.8413 - val_loss: 0.3764 - val_categorical_accuracy: 0.8000
#
# Epoch 00028: saving model to model_init_2020-07-1220_19_19.720565/model-00028-0.42992-0.84127-0.37640-0.80000.h5
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 1.164153273563659e-13.
# Epoch 29/30
# 14/14 [==============================] - 6s 398ms/step - loss: 0.3200 - categorical_accuracy: 0.8492 - val_loss: 0.1952 - val_categorical_accuracy: 0.9000
#
# Epoch 00029: saving model to model_init_2020-07-1220_19_19.720565/model-00029-0.32004-0.84921-0.19518-0.90000.h5
# Epoch 30/30
# 14/14 [==============================] - 6s 426ms/step - loss: 0.2614 - categorical_accuracy: 0.9127 - val_loss: 0.3055 - val_categorical_accuracy: 0.9000
#
# Epoch 00030: saving model to model_init_2020-07-1220_19_19.720565/model-00030-0.26139-0.91270-0.30551-0.90000.h5

# %% [markdown]
# ## CNN_Model5

# %%
batch_size = 90
num_epochs = 30

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/30
# 8/8 [==============================] - 4s 512ms/step - loss: 0.0957 - categorical_accuracy: 0.9583 - val_loss: 0.4288 - val_categorical_accuracy: 0.8000
#
# Epoch 00001: saving model to model_init_2020-07-1220_19_19.720565/model-00001-0.09574-0.95833-0.42879-0.80000.h5
# Epoch 2/30
# 8/8 [==============================] - 4s 449ms/step - loss: 0.2991 - categorical_accuracy: 0.9028 - val_loss: 0.5371 - val_categorical_accuracy: 0.9000
#
# Epoch 00002: saving model to model_init_2020-07-1220_19_19.720565/model-00002-0.29905-0.90278-0.53714-0.90000.h5
# Epoch 3/30
# 8/8 [==============================] - 3s 432ms/step - loss: 0.2238 - categorical_accuracy: 0.9306 - val_loss: 0.4172 - val_categorical_accuracy: 0.8000
#
# Epoch 00003: saving model to model_init_2020-07-1220_19_19.720565/model-00003-0.22383-0.93056-0.41720-0.80000.h5
# Epoch 4/30
# 8/8 [==============================] - 3s 424ms/step - loss: 0.2864 - categorical_accuracy: 0.8750 - val_loss: 0.2190 - val_categorical_accuracy: 1.0000
#
# Epoch 00004: saving model to model_init_2020-07-1220_19_19.720565/model-00004-0.28644-0.87500-0.21896-1.00000.h5
# Epoch 5/30
# 8/8 [==============================] - 3s 426ms/step - loss: 0.3864 - categorical_accuracy: 0.8472 - val_loss: 0.7655 - val_categorical_accuracy: 0.6000
#
# Epoch 00005: saving model to model_init_2020-07-1220_19_19.720565/model-00005-0.38636-0.84722-0.76553-0.60000.h5
# Epoch 6/30
# 8/8 [==============================] - 4s 500ms/step - loss: 0.2280 - categorical_accuracy: 0.9167 - val_loss: 0.4128 - val_categorical_accuracy: 0.8000
#
# Epoch 00006: saving model to model_init_2020-07-1220_19_19.720565/model-00006-0.22797-0.91667-0.41285-0.80000.h5
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 5.820766367818295e-14.
# Epoch 7/30
# 8/8 [==============================] - 3s 424ms/step - loss: 0.2928 - categorical_accuracy: 0.8750 - val_loss: 0.1246 - val_categorical_accuracy: 0.9500
#
# Epoch 00007: saving model to model_init_2020-07-1220_19_19.720565/model-00007-0.29277-0.87500-0.12457-0.95000.h5
# Epoch 8/30
# 8/8 [==============================] - 3s 426ms/step - loss: 0.1397 - categorical_accuracy: 0.9722 - val_loss: 0.5726 - val_categorical_accuracy: 0.8500
#
# Epoch 00008: saving model to model_init_2020-07-1220_19_19.720565/model-00008-0.13975-0.97222-0.57257-0.85000.h5
# Epoch 9/30
# 8/8 [==============================] - 4s 495ms/step - loss: 0.2359 - categorical_accuracy: 0.9444 - val_loss: 0.5873 - val_categorical_accuracy: 0.7000
#
# Epoch 00009: saving model to model_init_2020-07-1220_19_19.720565/model-00009-0.23589-0.94444-0.58729-0.70000.h5
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 2.9103831839091474e-14.
# Epoch 10/30
# 8/8 [==============================] - 4s 471ms/step - loss: 0.2862 - categorical_accuracy: 0.9306 - val_loss: 0.4842 - val_categorical_accuracy: 0.8000
#
# Epoch 00010: saving model to model_init_2020-07-1220_19_19.720565/model-00010-0.28618-0.93056-0.48425-0.80000.h5
# Epoch 11/30
# 8/8 [==============================] - 3s 437ms/step - loss: 0.2445 - categorical_accuracy: 0.9028 - val_loss: 0.2334 - val_categorical_accuracy: 0.8500
#
# Epoch 00011: saving model to model_init_2020-07-1220_19_19.720565/model-00011-0.24447-0.90278-0.23337-0.85000.h5
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 1.4551915919545737e-14.
# Epoch 12/30
# 8/8 [==============================] - 3s 418ms/step - loss: 0.3683 - categorical_accuracy: 0.8472 - val_loss: 0.1690 - val_categorical_accuracy: 0.9500
#
# Epoch 00012: saving model to model_init_2020-07-1220_19_19.720565/model-00012-0.36828-0.84722-0.16901-0.95000.h5
# Epoch 13/30
# 8/8 [==============================] - 4s 451ms/step - loss: 0.2024 - categorical_accuracy: 0.9444 - val_loss: 0.6298 - val_categorical_accuracy: 0.8500
#
# Epoch 00013: saving model to model_init_2020-07-1220_19_19.720565/model-00013-0.20241-0.94444-0.62978-0.85000.h5
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 7.275957959772868e-15.
# Epoch 14/30
# 8/8 [==============================] - 3s 409ms/step - loss: 0.1699 - categorical_accuracy: 0.9306 - val_loss: 0.4846 - val_categorical_accuracy: 0.8000
#
# Epoch 00014: saving model to model_init_2020-07-1220_19_19.720565/model-00014-0.16985-0.93056-0.48462-0.80000.h5
# Epoch 15/30
# 8/8 [==============================] - 4s 490ms/step - loss: 0.1427 - categorical_accuracy: 0.9583 - val_loss: 0.3989 - val_categorical_accuracy: 0.7500
#
# Epoch 00015: saving model to model_init_2020-07-1220_19_19.720565/model-00015-0.14268-0.95833-0.39889-0.75000.h5
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 3.637978979886434e-15.
# Epoch 16/30
# 8/8 [==============================] - 3s 435ms/step - loss: 0.3676 - categorical_accuracy: 0.8333 - val_loss: 0.4088 - val_categorical_accuracy: 0.9000
#
# Epoch 00016: saving model to model_init_2020-07-1220_19_19.720565/model-00016-0.36757-0.83333-0.40877-0.90000.h5
# Epoch 17/30
# 8/8 [==============================] - 3s 430ms/step - loss: 0.3529 - categorical_accuracy: 0.8472 - val_loss: 0.6163 - val_categorical_accuracy: 0.8500
#
# Epoch 00017: saving model to model_init_2020-07-1220_19_19.720565/model-00017-0.35293-0.84722-0.61629-0.85000.h5
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 1.818989489943217e-15.
# Epoch 18/30
# 8/8 [==============================] - 4s 494ms/step - loss: 0.2916 - categorical_accuracy: 0.9028 - val_loss: 0.1993 - val_categorical_accuracy: 0.8500
#
# Epoch 00018: saving model to model_init_2020-07-1220_19_19.720565/model-00018-0.29160-0.90278-0.19930-0.85000.h5
# Epoch 19/30
# 8/8 [==============================] - 4s 451ms/step - loss: 0.3875 - categorical_accuracy: 0.8611 - val_loss: 0.3612 - val_categorical_accuracy: 0.8500
#
# Epoch 00019: saving model to model_init_2020-07-1220_19_19.720565/model-00019-0.38753-0.86111-0.36118-0.85000.h5
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 9.094947449716085e-16.
# Epoch 20/30
# 8/8 [==============================] - 4s 478ms/step - loss: 0.3154 - categorical_accuracy: 0.8889 - val_loss: 0.2145 - val_categorical_accuracy: 0.9000
#
# Epoch 00020: saving model to model_init_2020-07-1220_19_19.720565/model-00020-0.31540-0.88889-0.21453-0.90000.h5
# Epoch 21/30
# 8/8 [==============================] - 3s 427ms/step - loss: 0.2101 - categorical_accuracy: 0.9306 - val_loss: 0.2914 - val_categorical_accuracy: 0.8500
#
# Epoch 00021: saving model to model_init_2020-07-1220_19_19.720565/model-00021-0.21012-0.93056-0.29142-0.85000.h5
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 4.547473724858043e-16.
# Epoch 22/30
# 8/8 [==============================] - 4s 458ms/step - loss: 0.2475 - categorical_accuracy: 0.8750 - val_loss: 0.7532 - val_categorical_accuracy: 0.8000
#
# Epoch 00022: saving model to model_init_2020-07-1220_19_19.720565/model-00022-0.24753-0.87500-0.75325-0.80000.h5
# Epoch 23/30
# 8/8 [==============================] - 4s 450ms/step - loss: 0.1002 - categorical_accuracy: 0.9583 - val_loss: 0.4750 - val_categorical_accuracy: 0.7500
#
# Epoch 00023: saving model to model_init_2020-07-1220_19_19.720565/model-00023-0.10023-0.95833-0.47503-0.75000.h5
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 2.2737368624290214e-16.
# Epoch 24/30
# 8/8 [==============================] - 4s 463ms/step - loss: 0.3388 - categorical_accuracy: 0.8611 - val_loss: 0.4671 - val_categorical_accuracy: 0.8500
#
# Epoch 00024: saving model to model_init_2020-07-1220_19_19.720565/model-00024-0.33875-0.86111-0.46709-0.85000.h5
# Epoch 25/30
# 8/8 [==============================] - 4s 440ms/step - loss: 0.3904 - categorical_accuracy: 0.7917 - val_loss: 0.2103 - val_categorical_accuracy: 0.9000
#
# Epoch 00025: saving model to model_init_2020-07-1220_19_19.720565/model-00025-0.39044-0.79167-0.21031-0.90000.h5
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 1.1368684312145107e-16.
# Epoch 26/30
# 8/8 [==============================] - 3s 426ms/step - loss: 0.3000 - categorical_accuracy: 0.8750 - val_loss: 0.4787 - val_categorical_accuracy: 0.7500
#
# Epoch 00026: saving model to model_init_2020-07-1220_19_19.720565/model-00026-0.29998-0.87500-0.47875-0.75000.h5
# Epoch 27/30
# 8/8 [==============================] - 3s 404ms/step - loss: 0.1567 - categorical_accuracy: 0.9444 - val_loss: 0.2780 - val_categorical_accuracy: 0.8000
# Epoch 00027: saving model to model_init_2020-07-1220_19_19.720565/model-00027-0.15668-0.94444-0.27798-0.80000.h5
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 5.684342156072553e-17.
# Epoch 28/30
# 8/8 [==============================] - 3s 427ms/step - loss: 0.3612 - categorical_accuracy: 0.8472 - val_loss: 0.6617 - val_categorical_accuracy: 0.8500
#
# Epoch 00028: saving model to model_init_2020-07-1220_19_19.720565/model-00028-0.36122-0.84722-0.66175-0.85000.h5
# Epoch 29/30
# 8/8 [==============================] - 4s 444ms/step - loss: 0.3135 - categorical_accuracy: 0.8333 - val_loss: 0.2980 - val_categorical_accuracy: 0.9000
#
# Epoch 00029: saving model to model_init_2020-07-1220_19_19.720565/model-00029-0.31352-0.83333-0.29799-0.90000.h5
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 2.842171078036277e-17.
# Epoch 30/30
# 8/8 [==============================] - 4s 453ms/step - loss: 0.1628 - categorical_accuracy: 0.9444 - val_loss: 0.4444 - val_categorical_accuracy: 0.7500
#
# Epoch 00030: saving model to model_init_2020-07-1220_19_19.720565/model-00030-0.16282-0.94444-0.44435-0.75000.h5

# %% [markdown]
# ## CNN_Model6

# %%
batch_size = 8
num_epochs = 25

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/25
# 83/83 [==============================] - 37s 443ms/step - loss: 0.3055 - categorical_accuracy: 0.8942 - val_loss: 0.4189 - val_categorical_accuracy: 0.8538
#
# Epoch 00001: saving model to model_init_2020-07-1220_19_19.720565/model-00001-0.30549-0.89424-0.41889-0.85385.h5
# Epoch 2/25
# 83/83 [==============================] - 34s 413ms/step - loss: 0.2465 - categorical_accuracy: 0.9143 - val_loss: 0.3479 - val_categorical_accuracy: 0.8462
#
# Epoch 00002: saving model to model_init_2020-07-1220_19_19.720565/model-00002-0.24647-0.91432-0.34788-0.84615.h5
# Epoch 3/25
# 83/83 [==============================] - 33s 398ms/step - loss: 0.3053 - categorical_accuracy: 0.8728 - val_loss: 0.4014 - val_categorical_accuracy: 0.8385
#
# Epoch 00003: saving model to model_init_2020-07-1220_19_19.720565/model-00003-0.30527-0.87282-0.40143-0.83846.h5
# Epoch 4/25
# 83/83 [==============================] - 36s 437ms/step - loss: 0.2668 - categorical_accuracy: 0.9063 - val_loss: 0.4522 - val_categorical_accuracy: 0.8000
#
# Epoch 00004: saving model to model_init_2020-07-1220_19_19.720565/model-00004-0.26681-0.90629-0.45220-0.80000.h5
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 8.470329874862065e-25.
# Epoch 5/25
# 83/83 [==============================] - 34s 410ms/step - loss: 0.2891 - categorical_accuracy: 0.8969 - val_loss: 0.3737 - val_categorical_accuracy: 0.8462
#
# Epoch 00005: saving model to model_init_2020-07-1220_19_19.720565/model-00005-0.28908-0.89692-0.37375-0.84615.h5
# Epoch 6/25
# 83/83 [==============================] - 35s 420ms/step - loss: 0.3136 - categorical_accuracy: 0.8795 - val_loss: 0.4597 - val_categorical_accuracy: 0.8308
#
# Epoch 00006: saving model to model_init_2020-07-1220_19_19.720565/model-00006-0.31363-0.87952-0.45973-0.83077.h5
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 4.2351649374310325e-25.
# Epoch 7/25
# 83/83 [==============================] - 35s 417ms/step - loss: 0.2505 - categorical_accuracy: 0.9264 - val_loss: 0.4101 - val_categorical_accuracy: 0.8308
#
# Epoch 00007: saving model to model_init_2020-07-1220_19_19.720565/model-00007-0.25050-0.92637-0.41009-0.83077.h5
# Epoch 8/25
# 83/83 [==============================] - 34s 414ms/step - loss: 0.2404 - categorical_accuracy: 0.9143 - val_loss: 0.4476 - val_categorical_accuracy: 0.8308
#
# Epoch 00008: saving model to model_init_2020-07-1220_19_19.720565/model-00008-0.24041-0.91432-0.44765-0.83077.h5
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 2.1175824687155163e-25.
# Epoch 9/25
# 83/83 [==============================] - 34s 415ms/step - loss: 0.2635 - categorical_accuracy: 0.8996 - val_loss: 0.4104 - val_categorical_accuracy: 0.8154
#
# Epoch 00009: saving model to model_init_2020-07-1220_19_19.720565/model-00009-0.26351-0.89960-0.41041-0.81538.h5
# Epoch 10/25
# 83/83 [==============================] - 34s 410ms/step - loss: 0.2810 - categorical_accuracy: 0.8929 - val_loss: 0.4817 - val_categorical_accuracy: 0.8077
#
# Epoch 00010: saving model to model_init_2020-07-1220_19_19.720565/model-00010-0.28099-0.89290-0.48166-0.80769.h5
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 1.0587912343577581e-25.
# Epoch 11/25
# 83/83 [==============================] - 34s 408ms/step - loss: 0.2749 - categorical_accuracy: 0.8996 - val_loss: 0.2977 - val_categorical_accuracy: 0.8538
#
# Epoch 00011: saving model to model_init_2020-07-1220_19_19.720565/model-00011-0.27485-0.89960-0.29766-0.85385.h5
# Epoch 12/25
# 83/83 [==============================] - 35s 417ms/step - loss: 0.3028 - categorical_accuracy: 0.8835 - val_loss: 0.4973 - val_categorical_accuracy: 0.8000
#
# Epoch 00012: saving model to model_init_2020-07-1220_19_19.720565/model-00012-0.30278-0.88353-0.49732-0.80000.h5
# Epoch 13/25
# 83/83 [==============================] - 36s 431ms/step - loss: 0.2426 - categorical_accuracy: 0.9183 - val_loss: 0.3794 - val_categorical_accuracy: 0.8385
#
# Epoch 00013: saving model to model_init_2020-07-1220_19_19.720565/model-00013-0.24265-0.91834-0.37935-0.83846.h5
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 5.293956171788791e-26.
# Epoch 14/25
# 83/83 [==============================] - 34s 413ms/step - loss: 0.3316 - categorical_accuracy: 0.8742 - val_loss: 0.3861 - val_categorical_accuracy: 0.8308
#
# Epoch 00014: saving model to model_init_2020-07-1220_19_19.720565/model-00014-0.33160-0.87416-0.38613-0.83077.h5
# Epoch 15/25
# 83/83 [==============================] - 34s 409ms/step - loss: 0.3291 - categorical_accuracy: 0.8715 - val_loss: 0.4437 - val_categorical_accuracy: 0.8462
#
# Epoch 00015: saving model to model_init_2020-07-1220_19_19.720565/model-00015-0.32915-0.87149-0.44367-0.84615.h5
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 2.6469780858943953e-26.
# Epoch 16/25
# 83/83 [==============================] - 33s 400ms/step - loss: 0.2489 - categorical_accuracy: 0.9183 - val_loss: 0.4399 - val_categorical_accuracy: 0.8154
#
# Epoch 00016: saving model to model_init_2020-07-1220_19_19.720565/model-00016-0.24891-0.91834-0.43989-0.81538.h5
# Epoch 17/25
# 83/83 [==============================] - 33s 402ms/step - loss: 0.2914 - categorical_accuracy: 0.8876 - val_loss: 0.4129 - val_categorical_accuracy: 0.8308
#
# Epoch 00017: saving model to model_init_2020-07-1220_19_19.720565/model-00017-0.29142-0.88755-0.41288-0.83077.h5
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 1.3234890429471977e-26.
# Epoch 18/25
# 83/83 [==============================] - 36s 433ms/step - loss: 0.2874 - categorical_accuracy: 0.8929 - val_loss: 0.4712 - val_categorical_accuracy: 0.8154
#
# Epoch 00018: saving model to model_init_2020-07-1220_19_19.720565/model-00018-0.28742-0.89290-0.47117-0.81538.h5
# Epoch 19/25
# 83/83 [==============================] - 35s 424ms/step - loss: 0.2645 - categorical_accuracy: 0.9036 - val_loss: 0.3850 - val_categorical_accuracy: 0.8231
#
# Epoch 00019: saving model to model_init_2020-07-1220_19_19.720565/model-00019-0.26446-0.90361-0.38496-0.82308.h5
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 6.617445214735988e-27.
# Epoch 20/25
# 83/83 [==============================] - 34s 415ms/step - loss: 0.3178 - categorical_accuracy: 0.8889 - val_loss: 0.4148 - val_categorical_accuracy: 0.8231
#
# Epoch 00020: saving model to model_init_2020-07-1220_19_19.720565/model-00020-0.31782-0.88889-0.41481-0.82308.h5
# Epoch 21/25
# 83/83 [==============================] - 35s 424ms/step - loss: 0.2924 - categorical_accuracy: 0.9023 - val_loss: 0.4470 - val_categorical_accuracy: 0.8077
#
# Epoch 00021: saving model to model_init_2020-07-1220_19_19.720565/model-00021-0.29243-0.90228-0.44697-0.80769.h5
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 3.308722607367994e-27.
# Epoch 22/25
# 83/83 [==============================] - 34s 407ms/step - loss: 0.2796 - categorical_accuracy: 0.8956 - val_loss: 0.3968 - val_categorical_accuracy: 0.8538
#
# Epoch 00022: saving model to model_init_2020-07-1220_19_19.720565/model-00022-0.27956-0.89558-0.39676-0.85385.h5
# Epoch 23/25
# 83/83 [==============================] - 34s 407ms/step - loss: 0.2441 - categorical_accuracy: 0.9090 - val_loss: 0.4333 - val_categorical_accuracy: 0.8231
#
# Epoch 00023: saving model to model_init_2020-07-1220_19_19.720565/model-00023-0.24405-0.90897-0.43333-0.82308.h5
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 1.654361303683997e-27.
# Epoch 24/25
# 83/83 [==============================] - 35s 416ms/step - loss: 0.2707 - categorical_accuracy: 0.9170 - val_loss: 0.4424 - val_categorical_accuracy: 0.8385
#
# Epoch 00024: saving model to model_init_2020-07-1220_19_19.720565/model-00024-0.27072-0.91700-0.44236-0.83846.h5
# Epoch 25/25
# 83/83 [==============================] - 35s 425ms/step - loss: 0.2670 - categorical_accuracy: 0.9090 - val_loss: 0.3752 - val_categorical_accuracy: 0.8615
#
# Epoch 00025: saving model to model_init_2020-07-1220_19_19.720565/model-00025-0.26697-0.90897-0.37525-0.86154.h5
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 8.271806518419985e-28.

# %% [markdown]
# ## RNN_Model

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation, Dropout
from keras.layers.convolutional import Conv3D,Conv2D, MaxPooling3D, MaxPooling2D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras import optimizers
from keras.applications import ResNet50
from keras.applications.resnet50 import preprocess_input
from keras.layers.recurrent import LSTM, GRU

#write your model here

#RNN
# input_shape=(nb_frames,nb_rows,nb_cols,nb_channel)
nb_classes = 5
nb_featuremap = [8,16,32,64,128,256]
nb_dense = [128,64,5]

model = Sequential()



model.add(TimeDistributed(Conv2D(nb_featuremap[0], (3, 3), strides=(2, 2),activation='relu', padding='same'), input_shape=input_shape))


model.add(TimeDistributed(Conv2D(nb_featuremap[1], (3,3),padding='same', activation='relu')))

model.add(TimeDistributed(MaxPooling2D((2, 2), strides=(2, 2))))

model.add(TimeDistributed(Conv2D(nb_featuremap[2], (3,3),padding='same', activation='relu')))

model.add(TimeDistributed(MaxPooling2D((2, 2), strides=(2, 2))))

model.add(TimeDistributed(Conv2D(nb_featuremap[3], (2,2),padding='same', activation='relu')))

model.add(TimeDistributed(MaxPooling2D((2, 2), strides=(2, 2))))


model.add(TimeDistributed(BatchNormalization()))
model.add(Dropout(0.25))

model.add(TimeDistributed(Flatten()))

model.add(Dense(nb_dense[0], activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(nb_dense[1], activation='relu'))
model.add(Dropout(0.25))


model.add(GRU(128, return_sequences=False))
model.add(Dense(nb_classes, activation='softmax'))

# %%
from keras.optimizers import Adam

optimiser = Adam()#write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed_37 (TimeDis (None, 30, 60, 60, 8)     224
# _________________________________________________________________
# time_distributed_38 (TimeDis (None, 30, 60, 60, 16)    1168
# _________________________________________________________________
# time_distributed_39 (TimeDis (None, 30, 30, 30, 16)    0
# _________________________________________________________________
# time_distributed_40 (TimeDis (None, 30, 30, 30, 32)    4640
# _________________________________________________________________
# time_distributed_41 (TimeDis (None, 30, 15, 15, 32)    0
# _________________________________________________________________
# time_distributed_42 (TimeDis (None, 30, 15, 15, 64)    8256
# _________________________________________________________________
# time_distributed_43 (TimeDis (None, 30, 7, 7, 64)      0
# _________________________________________________________________
# time_distributed_44 (TimeDis (None, 30, 7, 7, 64)      256
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 30, 7, 7, 64)      0
# _________________________________________________________________
# time_distributed_45 (TimeDis (None, 30, 3136)          0
# _________________________________________________________________
# dense_16 (Dense)             (None, 30, 128)           401536
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 30, 128)           0
# _________________________________________________________________
# dense_17 (Dense)             (None, 30, 64)            8256
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 30, 64)            0
# _________________________________________________________________
# gru_5 (GRU)                  (None, 128)               74112
# _________________________________________________________________
# dense_18 (Dense)             (None, 5)                 645
# =================================================================
# Total params: 499,093
# Trainable params: 498,965
# Non-trainable params: 128
# _________________________________________________________________
# None

# %%
train_generator = generator_augmentation(train_path, train_doc, batch_size)

val_generator = generator_augmentation(train_path, train_doc, batch_size)

# %%
model_name = 'model_rnn/model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, cooldown=1, verbose=1)# write the REducelronplateau code here
callbacks_list = [checkpoint, LR]

# %%
batch_size = 25
num_epochs = 16


if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %%
model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  train ; batch size = 10
# Source path =  train ; batch size =Epoch 1/16
#  10
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# 27/27 [==============================] - 56s 2s/step - loss: 1.3449 - categorical_accuracy: 0.4296 - val_loss: 1.3229 - val_categorical_accuracy: 0.4750
#
# Epoch 00001: saving model to model_rnn/model_init_2020-07-1221_14_58.428971/model-00001-1.34491-0.42963-1.32294-0.47500.h5
# Epoch 2/16
# 27/27 [==============================] - 46s 2s/step - loss: 1.2433 - categorical_accuracy: 0.4704 - val_loss: 0.8760 - val_categorical_accuracy: 0.6375
#
# Epoch 00002: saving model to model_rnn/model_init_2020-07-1221_14_58.428971/model-00002-1.24325-0.47037-0.87599-0.63750.h5
# Epoch 3/16
# 27/27 [==============================] - 31s 1s/step - loss: 1.0094 - categorical_accuracy: 0.5932 - val_loss: 1.5392 - val_categorical_accuracy: 0.5375
#
# Epoch 00003: saving model to model_rnn/model_init_2020-07-1221_14_58.428971/model-00003-1.00313-0.57576-1.53918-0.53750.h5
# Epoch 4/16
# 27/27 [==============================] - 17s 644ms/step - loss: 1.3239 - categorical_accuracy: 0.5185 - val_loss: 1.1664 - val_categorical_accuracy: 0.5375
#
# Epoch 00004: saving model to model_rnn/model_init_2020-07-1221_14_58.428971/model-00004-1.32389-0.51852-1.16637-0.53750.h5
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 5/16
# 27/27 [==============================] - 16s 608ms/step - loss: 1.2581 - categorical_accuracy: 0.4630 - val_loss: 0.8711 - val_categorical_accuracy: 0.6375
#
# Epoch 00005: saving model to model_rnn/model_init_2020-07-1221_14_58.428971/model-00005-1.25811-0.46296-0.87110-0.63750.h5
# Epoch 6/16
# 27/27 [==============================] - 16s 607ms/step - loss: 1.0719 - categorical_accuracy: 0.5309 - val_loss: 0.6920 - val_categorical_accuracy: 0.7000
#
# Epoch 00006: saving model to model_rnn/model_init_2020-07-1221_14_58.428971/model-00006-1.07188-0.53086-0.69202-0.70000.h5
# Epoch 7/16
# 27/27 [==============================] - 17s 646ms/step - loss: 0.8613 - categorical_accuracy: 0.6667 - val_loss: 0.6363 - val_categorical_accuracy: 0.7125
#
# Epoch 00007: saving model to model_rnn/model_init_2020-07-1221_14_58.428971/model-00007-0.86130-0.66667-0.63632-0.71250.h5
# Epoch 8/16
# 27/27 [==============================] - 16s 611ms/step - loss: 0.9110 - categorical_accuracy: 0.6605 - val_loss: 0.6534 - val_categorical_accuracy: 0.8125
#
# Epoch 00008: saving model to model_rnn/model_init_2020-07-1221_14_58.428971/model-00008-0.91099-0.66049-0.65345-0.81250.h5
# Epoch 9/16
# 27/27 [==============================] - 16s 602ms/step - loss: 0.9749 - categorical_accuracy: 0.5988 - val_loss: 0.5719 - val_categorical_accuracy: 0.8000
#
# Epoch 00009: saving model to model_rnn/model_init_2020-07-1221_14_58.428971/model-00009-0.97488-0.59877-0.57192-0.80000.h5
# Epoch 10/16
# 27/27 [==============================] - 17s 639ms/step - loss: 0.8515 - categorical_accuracy: 0.6852 - val_loss: 0.8552 - val_categorical_accuracy: 0.6125
#
# Epoch 00010: saving model to model_rnn/model_init_2020-07-1221_14_58.428971/model-00010-0.85152-0.68519-0.85519-0.61250.h5
# Epoch 11/16
# 27/27 [==============================] - 16s 599ms/step - loss: 0.7912 - categorical_accuracy: 0.7222 - val_loss: 0.9580 - val_categorical_accuracy: 0.7250
#
# Epoch 00011: saving model to model_rnn/model_init_2020-07-1221_14_58.428971/model-00011-0.79118-0.72222-0.95804-0.72500.h5
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 12/16
# 27/27 [==============================] - 17s 631ms/step - loss: 0.5785 - categorical_accuracy: 0.7963 - val_loss: 0.5610 - val_categorical_accuracy: 0.8375
#
# Epoch 00012: saving model to model_rnn/model_init_2020-07-1221_14_58.428971/model-00012-0.57852-0.79630-0.56095-0.83750.h5
# Epoch 13/16
# 27/27 [==============================] - 17s 628ms/step - loss: 0.5979 - categorical_accuracy: 0.7654 - val_loss: 0.3133 - val_categorical_accuracy: 0.8750
#
# Epoch 00013: saving model to model_rnn/model_init_2020-07-1221_14_58.428971/model-00013-0.59791-0.76543-0.31331-0.87500.h5
# Epoch 14/16
# 27/27 [==============================] - 17s 643ms/step - loss: 0.5210 - categorical_accuracy: 0.8025 - val_loss: 0.2666 - val_categorical_accuracy: 0.8875
#
# Epoch 00014: saving model to model_rnn/model_init_2020-07-1221_14_58.428971/model-00014-0.52101-0.80247-0.26664-0.88750.h5
# Epoch 15/16
# 27/27 [==============================] - 17s 624ms/step - loss: 0.3277 - categorical_accuracy: 0.8951 - val_loss: 0.1923 - val_categorical_accuracy: 0.9750
#
# Epoch 00015: saving model to model_rnn/model_init_2020-07-1221_14_58.428971/model-00015-0.32770-0.89506-0.19233-0.97500.h5
# Epoch 16/16
# 27/27 [==============================] - 16s 574ms/step - loss: 0.4438 - categorical_accuracy: 0.8333 - val_loss: 0.2512 - val_categorical_accuracy: 0.9250
#
# Epoch 00016: saving model to model_rnn/model_init_2020-07-1221_14_58.428971/model-00016-0.44380-0.83333-0.25120-0.92500.h5

# %% [markdown]
# ### Summary of the metrics for the final model

# %% [markdown]
# | Model | Categorical-Accuracy| Validation_categorical _Accuracy|
# | --- | --- | --- |
# | CNN_Model 1 |0.81 | 78 |
# | CNN_Model 2 |0.91| 0.90 |
# | CNN_Model 3 |0.89| 0.95|
# | CNN_Model 4 |0.91| 0.90|
# | CNN_Model 5 |0.89 | 0.85|
# | CNN_Model 6 |0.88 | 0.90 |
# | RNN_model |0.89 | 0.97 |

# %% [markdown]
# ### Conclusion:
# We chose CNN_ model 4 with batch size :50 and epoch :30
#
# Reasons:
# - time consumed by the model for training was between 5s-6s per epoch which much better the other models used in the experiment
# - Since the model used will used on daily basis for watching the television the response rate needs to high so we decided to go with categorical accuracy of 91 and validation accuracy of 90
